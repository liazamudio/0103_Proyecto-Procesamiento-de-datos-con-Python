# %% [markdown]
# ### Configuración

# %%
# Instalación de MySQL Connector Python y Pandas
# !pip install mysql-connector-python
# !pip install pandas
# Out:
# Requirement already satisfied: mysql-connector-python in c:\python310\lib\site-packages (8.2.0)
# Requirement already satisfied: protobuf<=4.21.12,>=4.21.1 in c:\python310\lib\site-packages (from mysql-connector-python) (4.21.12)
# Requirement already satisfied: pandas in c:\python310\lib\site-packages (2.1.2)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\python310\lib\site-packages (from pandas) (1.26.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\python310\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\python310\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\python310\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# Importación de MySQL Connector y Pandas
import mysql.connector
import pandas as pd

# %%
# Conexión a la base de datos de MySQL
cnx = mysql.connector.connect(
   host="localhost",
   port=3306,
   user="root",
   password='2023*DaSci',
   database='project_processpython'
)

# %%
# REVISAMOS TODAS LAS TABLAS DE LA BASE DE DATOS y Confirmamos el nombre de la tabla 5
# Realización de lecturas a nuestra base de datos creando un objeto llamado cursor.
cursor = cnx.cursor()
# Consulta de tablas
cursor.execute("SHOW TABLES")
#Extracción de información
all_tables = cursor.fetchall()
# all_tables

all_tables[5]

# Para cerrar el cursor
# cursor.close()
# Out:
# ('n14_flucaja',)

# %%
# Realización de lecturas a nuestra base de datos creando un objeto llamado cursor.
cursor = cnx.cursor()
# Consulta de la tabla FLUJOS DE EFECTIVO O CAJA (n14_flucaja)
cursor.execute("SELECT * FROM n14_flucaja")
#Extracción de información
flu_caja = cursor.fetchall()
# flu_caja

# Revisión de una fila
# flu_caja[0]

# Construimos el DataFrame FLUJOS DE EFECTIVO O CAJA (n14_flucaja)
df_flucaja = pd.DataFrame(flu_caja, columns=['clave_flucaja', 'ticker_flucaj', 'period_flucaj', 'obser_flucaj', 'cierre_flucaj', 'durper_flucaj', 'res_neto_flucaj', 'fne_actope_flucaj', 'depr_flucaj', 'amort_flucaj', 'impdif_flucaj', 'par_noefe_flucaj', 'entr_caja_flucaj', 'pag_efe_flucaj', 'isr_pagefe_flucaj', 'int_pagefe_flucaj', 'cam_opasope_flucaj', 'fne_actinv_flucaj', 'pagxadq_mobeq_flucaj', 'pagxadq_subsid_flucaj', 'fne_actfin_flucaj', 'incr_pxsraipnc_flucaj', 'tot_pagdiv_flucaj', 'emiacc_pag_flucaj', 'enideu_pag_flucaj', 'aju_fex_vartcinf_flucaj', 'var_ne_flucaj', 'saldo_efe_ape_flucaj', 'saldo_efe_cie_flucaj', 'flu_caja_libre_flucaj', 'crec_fcl_flucaj', 'rend_fcl_flucaj'])

# Convertir la columna clave_flucaja en índice 
df_flucaja = df_flucaja.set_index('clave_flucaja', drop=True)
df_flucaja.head()


# Para cerrar el cursor
# cursor.close()
# Out:
#               ticker_flucaj period_flucaj obser_flucaj cierre_flucaj  \
# clave_flucaja
# 9                    FCFE18         ANUAL                 2018-12-31
# 19                  EDUCA18         ANUAL                 2019-12-31
# 20                   FCFE18         ANUAL                 2019-12-31
# 21                   FMTY14         ANUAL                 2019-12-31
# 22                  FNOVA17         ANUAL                 2019-12-31
#
#               durper_flucaj  res_neto_flucaj  fne_actope_flucaj  depr_flucaj  \
# clave_flucaja
# 9                  12 meses          4165.93           12773.65         0.00
# 19                 12 meses          2641.07            2775.76         2.88
# 20                 12 meses          6277.28            3107.77         0.00
# 21                 12 meses           576.94            1238.58         5.15
# 22                 12 meses           582.16             416.70         0.19
#
#                amort_flucaj  impdif_flucaj  ...  tot_pagdiv_flucaj  \
# clave_flucaja                               ...
# 9                       0.0            0.0  ...            1145.88
# 19                      0.0            0.0  ...            2416.99
# 20                      0.0            0.0  ...            2934.57
# 21                      0.0            0.0  ...             712.11
# 22                      0.0            0.0  ...             393.65
#
#                emiacc_pag_flucaj  enideu_pag_flucaj  aju_fex_vartcinf_flucaj  \
# clave_flucaja
# 9                       16210.71               0.00                     0.00
# 19                          0.00               4.56                     0.00
# 20                          0.00               0.00                     0.00
# 21                       3887.66             117.04                    13.82
# 22                          0.00             553.13                     0.00
#
#                var_ne_flucaj  saldo_efe_ape_flucaj  saldo_efe_cie_flucaj  \
# clave_flucaja
# 9                    1073.76                  0.00                  0.00
# 19                   6101.10                  0.00                  0.00
# 20                   1028.56                  0.00                  0.00
# 21                   3134.52                609.03               3743.55
# 22                     56.06                  0.00                  0.00
#
#                flu_caja_libre_flucaj  crec_fcl_flucaj  rend_fcl_flucaj
# clave_flucaja
# 9                               0.00             0.00              0.0
# 19                              0.00             0.00              0.0
# 20                              0.00             0.00              0.0
# 21                            679.54           551.84              0.0
# 22                              0.00             0.00              0.0
#
# [5 rows x 31 columns]

# %% [markdown]
# ### Análisis preliminar de la tabla

# %%
# Dimensiones del DataFrame FLUJOS DE EFECTIVO O CAJA
df_flucaja.shape
# Out:
# (60, 31)

# %%
# Tipos de datos de DataFrame FLUJOS DE EFECTIVO O CAJA
df_flucaja.dtypes
# Out:
# ticker_flucaj               object
# period_flucaj               object
# obser_flucaj                object
# cierre_flucaj               object
# durper_flucaj               object
# res_neto_flucaj            float64
# fne_actope_flucaj          float64
# depr_flucaj                float64
# amort_flucaj               float64
# impdif_flucaj              float64
# par_noefe_flucaj           float64
# entr_caja_flucaj           float64
# pag_efe_flucaj             float64
# isr_pagefe_flucaj          float64
# int_pagefe_flucaj          float64
# cam_opasope_flucaj         float64
# fne_actinv_flucaj          float64
# pagxadq_mobeq_flucaj       float64
# pagxadq_subsid_flucaj      float64
# fne_actfin_flucaj          float64
# incr_pxsraipnc_flucaj      float64
# tot_pagdiv_flucaj          float64
# emiacc_pag_flucaj          float64
# enideu_pag_flucaj          float64
# aju_fex_vartcinf_flucaj    float64
# var_ne_flucaj              float64
# saldo_efe_ape_flucaj       float64
# saldo_efe_cie_flucaj       float64
# flu_caja_libre_flucaj      float64
# crec_fcl_flucaj            float64
# rend_fcl_flucaj            float64
# dtype: object

# %% [markdown]
# ### Despliegue del DataFrame

# %%
# Despliegue final de todo el DataFrame FLUJOS DE EFECTIVO O CAJA. Solo se mostrarán algunos resultados.
df_flucaja.head(25)
# Out:
#               ticker_flucaj period_flucaj obser_flucaj cierre_flucaj  \
# clave_flucaja
# 9                    FCFE18         ANUAL                 2018-12-31
# 19                  EDUCA18         ANUAL                 2019-12-31
# 20                   FCFE18         ANUAL                 2019-12-31
# 21                   FMTY14         ANUAL                 2019-12-31
# 22                  FNOVA17         ANUAL                 2019-12-31
# 23                  FSHOP13         ANUAL                 2019-12-31
# 24                   FUNO11         ANUAL                 2019-12-31
# 25                  TERRA13         ANUAL                 2019-12-31
# 35                  EDUCA18         ANUAL                 2020-12-31
# 36                   FCFE18         ANUAL                 2020-12-31
# 37                   FMTY14         ANUAL                 2020-12-31
# 38                  FNOVA17         ANUAL                 2020-12-31
# 39                  FSHOP13         ANUAL                 2020-12-31
# 40                   FUNO11         ANUAL                 2020-12-31
# 41                  TERRA13         ANUAL                 2020-12-31
# 44                   FCFE18    TRIMESTRAL                 2021-06-30
# 47                   FCFE18    TRIMESTRAL                 2021-09-30
# 64                  EDUCA18         ANUAL                 2021-12-31
# 65                   FCFE18         ANUAL                 2021-12-31
# 66                   FCFE18    TRIMESTRAL                 2021-12-31
# 67                   FMTY14         ANUAL                 2021-12-31
# 68                  FNOVA17         ANUAL                 2021-12-31
# 69                  FSHOP13         ANUAL                 2021-12-31
# 70                   FUNO11         ANUAL                 2021-12-31
# 71                  TERRA13         ANUAL                 2021-12-31
#
#               durper_flucaj  res_neto_flucaj  fne_actope_flucaj  depr_flucaj  \
# clave_flucaja
# 9                  12 meses          4165.93           12773.65         0.00
# 19                 12 meses          2641.07            2775.76         2.88
# 20                 12 meses          6277.28            3107.77         0.00
# 21                 12 meses           576.94            1238.58         5.15
# 22                 12 meses           582.16             416.70         0.19
# 23                 12 meses          1862.55            1101.33         9.99
# 24                 12 meses         18150.32           11666.70       297.52
# 25                 12 meses          2894.59            2418.75         0.00
# 35                 12 meses          3094.42            3254.79         2.94
# 36                 12 meses          2009.25            3510.06         0.00
# 37                 12 meses           158.06             896.04         5.36
# 38                 12 meses           673.82             224.14         0.10
# 39                 12 meses          1479.49             622.13         8.75
# 40                 12 meses         12974.25           14937.87       229.07
# 41                 12 meses          1043.34            3168.12         0.00
# 44                  6 meses          3923.50            1315.94         0.00
# 47                  9 meses          2315.87            2386.77         0.00
# 64                 12 meses          3832.26            3101.94         2.95
# 65                 12 meses          5611.18            3348.47         0.00
# 66                 12 meses          5611.18            3348.47         0.00
# 67                  0 meses          1605.08            1104.42         5.57
# 68                 12 meses           822.20             650.32         0.12
# 69                  0 meses           985.91             976.92        12.03
# 70                  0 meses          3659.54           18112.96       219.86
# 71                  0 meses          6175.55            2725.86         0.00
#
#                amort_flucaj  impdif_flucaj  ...  tot_pagdiv_flucaj  \
# clave_flucaja                               ...
# 9                     0.000            0.0  ...            1145.88
# 19                    0.000            0.0  ...            2416.99
# 20                    0.000            0.0  ...            2934.57
# 21                    0.000            0.0  ...             712.11
# 22                    0.000            0.0  ...             393.65
# 23                    0.000            0.0  ...             427.62
# 24                  303.520            0.0  ...            9087.66
# 25                    0.000            0.0  ...            2274.00
# 35                    0.000            0.0  ...            2614.36
# 36                    0.000            0.0  ...            2208.53
# 37                    0.000            0.0  ...             936.15
# 38                    0.000            0.0  ...             438.17
# 39                    0.000            0.0  ...             200.12
# 40                  331.250            0.0  ...            5772.75
# 41                    0.000            0.0  ...            1888.86
# 44                    0.000            0.0  ...            1532.94
# 47                    0.000            0.0  ...            1415.05
# 64                    0.000            0.0  ...            2756.15
# 65                    0.000            0.0  ...            2311.28
# 66                    0.000            0.0  ...            2311.28
# 67                    0.000            0.0  ...             874.22
# 68                    0.000            0.0  ...             535.10
# 69                    0.000            0.0  ...             300.00
# 70                    0.001            0.0  ...            5156.93
# 71                    0.000            0.0  ...            1655.01
#
#                emiacc_pag_flucaj  enideu_pag_flucaj  aju_fex_vartcinf_flucaj  \
# clave_flucaja
# 9                       16210.71               0.00                    0.000
# 19                          0.00               4.56                    0.000
# 20                          0.00               0.00                    0.000
# 21                       3887.66             117.04                   13.820
# 22                          0.00             553.13                    0.000
# 23                         12.56             204.51                    0.000
# 24                          0.00           29595.65                    0.000
# 25                          0.00             896.51                  214.940
# 35                          0.00               4.71                    0.000
# 36                          0.00               0.00                    0.000
# 37                         26.84             823.18                   65.460
# 38                          3.70             905.70                    0.000
# 39                          0.00             330.57                    0.000
# 40                       1300.86           15181.24                 2158.950
# 41                          0.00            1742.59                  263.050
# 44                          0.00               0.00                    0.000
# 47                          0.00               0.00                    0.000
# 64                          0.00               4.89                    0.000
# 65                          0.00               0.00                    0.000
# 66                          0.00               0.00                    0.000
# 67                          0.42            1186.80                   12.860
# 68                        761.89            1637.46                    0.000
# 69                        300.00             600.00                    0.314
# 70                       1803.20            8780.96                 2422.980
# 71                         50.88              39.11                   31.220
#
#                var_ne_flucaj  saldo_efe_ape_flucaj  saldo_efe_cie_flucaj  \
# clave_flucaja
# 9                    1073.76                  0.00                  0.00
# 19                   6101.10                  0.00                  0.00
# 20                   1028.56                  0.00                  0.00
# 21                   3134.52                609.03               3743.55
# 22                     56.06                  0.00                  0.00
# 23                    187.20                288.61                 94.82
# 24                   1366.01                  0.00                  0.00
# 25                    291.33               1557.65               1266.32
# 35                    649.64                  0.00                  0.00
# 36                    213.73                  0.00                  0.00
# 37                   3035.75                  0.00                  0.00
# 38                      5.91                  0.00                  0.00
# 39                     14.23                  0.00                  0.00
# 40                   4703.68               3042.91               7746.59
# 41                    177.40                  0.00                  0.00
# 44                    212.78                  0.00                  0.00
# 47                    212.39                  0.00                  0.00
# 64                    279.18                  0.00                  0.00
# 65                    211.99                  0.00                  0.00
# 66                    211.99                  0.00                  0.00
# 67                    351.81                  0.00                  0.00
# 68                    127.46                  0.00                  0.00
# 69                     78.40                115.64                194.04
# 70                   1007.08               7746.59               6739.51
# 71                    390.97                  0.00                  0.00
#
#                flu_caja_libre_flucaj  crec_fcl_flucaj  rend_fcl_flucaj
# clave_flucaja
# 9                               0.00            0.000             0.00
# 19                              0.00            0.000             0.00
# 20                              0.00            0.000             0.00
# 21                            679.54          551.840             0.00
# 22                              0.00            0.000             0.00
# 23                           1123.31            0.000             0.00
# 24                              0.00            0.000             0.00
# 25                           2418.75            0.000             0.00
# 35                              0.00            0.000             0.00
# 36                              0.00            0.000             0.00
# 37                            672.74            1.000             0.00
# 38                              0.00            0.000             0.00
# 39                              0.00            0.000             0.00
# 40                           7619.67           27.690            20.02
# 41                              0.00            0.000             0.00
# 44                              0.00            0.000             0.00
# 47                              0.00            0.000             0.00
# 64                              0.00            0.000             0.00
# 65                              0.00            0.000             0.00
# 66                              0.00            0.000             0.00
# 67                            670.55            0.326             0.00
# 68                              0.00            0.000             0.00
# 69                             58.80          108.970            29.36
# 70                           7006.77            8.040            21.96
# 71                              0.00            0.000             0.00
#
# [25 rows x 31 columns]
