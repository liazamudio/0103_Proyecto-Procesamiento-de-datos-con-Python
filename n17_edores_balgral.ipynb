# %% [markdown]
# ### Configuración

# %%
# Instalación de MySQL Connector Python y Pandas
# !pip install mysql-connector-python
# !pip install pandas

# %%
# Importación de MySQL Connector y Pandas
import mysql.connector
import pandas as pd

# %%
# Conexión a la base de datos de MySQL
cnx = mysql.connector.connect(
   host="localhost",
   port=3306,
   user="root",
   password='2023*DaSci',
   database='project_processpython'
)

# %%
# REVISAMOS TODAS LAS TABLAS DE LA BASE DE DATOS y Confirmamos el nombre de la tabla 3
# Realización de lecturas a nuestra base de datos creando un objeto llamado cursor.
cursor = cnx.cursor()
# Consulta de tablas
cursor.execute("SHOW TABLES")
#Extracción de información
all_tables = cursor.fetchall()
# all_tables
all_tables[3]
# Para cerrar el cursor
# cursor.close()
# Out:
# ('n12_edores',)

# %%
# Realización de lecturas a nuestra base de datos creando objetos llamado cursor.
cursor = cnx.cursor()
cursor2 = cnx.cursor()

# Consulta de la tabla ESTADOS DE RESULTADOS (n12_edores) y generación del DataFrame
cursor.execute("SELECT * FROM n12_edores")
edo_res = cursor.fetchall()
df_edo_res = pd.DataFrame(edo_res, columns=['clave_edores', 'ticker_edores', 'perio_edores', 'observ_edores', 'cierre_edores', 'vnt_edores', 'vn_edores', 'ovt_edores', 'cosven_edores', 'uti_bru_edores', 'gto_ope_edores', 'gto_vag_edores', 'gto_dev_edores', 'gto_depamo_edores', 'gto_ine_edores', 'gto_ext_edores', 'gto_other_edores', 'uti_ope_edores', 'gto_inpr_edores', 'uti_vaf_edores', 'oth_net_edores', 'raim_edores', 'tot_imp_uti_edores', 'res_naiu_edores', 'par_nocon_edores', 'prsa_edores', 'gaap_edores', 'res_ape_redores', 'tot_parext_edores', 'res_neto_edores', 'aju_trn_edores', 'ing_disp_spe_edores', 'aju_dil_edores', 'dil_un_edores', 'dilprom_pa_edores', 'dil_gpaspe_edores', 'dpa_scdp_edores', 'dil_gpab_edores'])
df_edo_res = df_edo_res.set_index('clave_edores', drop=True)
# Solo OK

# Consulta de la tabla BALANCES GENERALES (n13_balgral) y generación del DataFrame
cursor2.execute("SELECT * FROM n13_balgral")
bal_gral = cursor2.fetchall()
df_bal_gral = pd.DataFrame(bal_gral, columns=['clave_balgral', 'ticker_balgral', 'perio_balgral', 'cierre_balbral', 'observ_balgral', 'tac_balgral', 'eicp_balgral', 'efectivo_balgral', 'eee_balgral', 'inv_cp_balgral', 'cxc_balgral', 'cxc_com_balgral', 'inven_balgral', 'pagant_balgral', 'oth_ac_balgral', 'tot_act_balgral', 'ime_neto_balgral', 'ime_bruto_balgral', 'dep_acum_balgral', 'cred_merc_balgral', 'intan_balgral', 'inver_per_balgral', 'docxc_lp_balgral', 'othact_per_balgral', 'othact_tot_balgral', 'tot_pas_c_balgral', 'cxp_balgral', 'cxp_obl_balgral', 'inv_cp2_balgral', 'docxpagar_balgral', 'deu_ec_oovn_balgral', 'oth_cxp_balgral', 'tot_pas_balgral', 'deu_lpt_balgral', 'deu_lp_balgral', 'obl_caf_balgral', 'imp_gandif_balgral', 'par_nocont_balgral', 'oth_pas_balgral', 'cap_con_balgral', 'ac_dirresc_balgral', 'cred_mer_balgral', 'acc_com_balgral', 'prim_venacc_balgral', 'res_ejean_balgral', 'acc_tes_balgral', 'esop_balgral', 'ganper_nre_balgral', 'oth_par_balgral', 'tot_pas_cc_balgral', 'tacc_balgral', 'tapc_balgral'])
df_bal_gral = df_bal_gral.set_index('clave_balgral', drop=True)
# Solo OK

# Despliegue de los DataFrames
# df_edo_res.head()
# df_bal_gral.head()
# Despliegue OK de ambos DataFrames

# Para cerrar el cursor
# cursor.close()

# %% [markdown]
# ### Análisis preliminar de la tabla

# %%
# Dimensiones del DataFrame ESTADOS DE RESULTADOS
df_edo_res.shape
# Out:
# (56, 37)

# %%
# Tipos de datos de DataFrame ESTADOS DE RESULTADOS
df_edo_res.dtypes
# Out:
# ticker_edores           object
# perio_edores            object
# observ_edores           object
# cierre_edores           object
# vnt_edores             float64
# vn_edores              float64
# ovt_edores             float64
# cosven_edores          float64
# uti_bru_edores         float64
# gto_ope_edores         float64
# gto_vag_edores         float64
# gto_dev_edores         float64
# gto_depamo_edores      float64
# gto_ine_edores         float64
# gto_ext_edores         float64
# gto_other_edores       float64
# uti_ope_edores         float64
# gto_inpr_edores        float64
# uti_vaf_edores         float64
# oth_net_edores         float64
# raim_edores            float64
# tot_imp_uti_edores     float64
# res_naiu_edores        float64
# par_nocon_edores       float64
# prsa_edores            float64
# gaap_edores            float64
# res_ape_redores        float64
# tot_parext_edores      float64
# res_neto_edores        float64
# aju_trn_edores         float64
# ...

# %% [markdown]
# ### Despliegue de los DataFrames

# %%
# Despliegue final de todo el DataFrame ESTADOS DE RESULTADOS. Solo se mostrarán algunos resultados debido 
# al gran tamaño de la tabla.
df_edo_res.head(25)
# Out:
#              ticker_edores perio_edores observ_edores cierre_edores  \
# clave_edores
# 9                   FCFE18        ANUAL                  2018-12-31
# 19                 EDUCA18        ANUAL                  2019-12-31
# 20                  FCFE18        ANUAL                  2019-12-31
# 21                  FMTY14        ANUAL                  2019-12-31
# 22                 FNOVA17        ANUAL                  2019-12-31
# 23                 FSHOP13        ANUAL                  2019-12-31
# 24                  FUNO11        ANUAL                  2019-12-31
# 34                 EDUCA18        ANUAL                  2020-12-31
# 35                  FCFE18        ANUAL                  2020-12-31
# 36                  FMTY14        ANUAL                  2020-12-31
# 37                 FNOVA17        ANUAL                  2020-12-31
# 38                 FSHOP13        ANUAL                  2020-12-31
# 39                  FUNO11        ANUAL                  2020-12-31
# ...

# %%
# Despliegue final de todo el DataFrame BALANCE GENERAL. Solo se mostrarán algunos resultados debido 
# al gran tamaño de la tabla.
df_bal_gral.head(25)
# Out:
#               ticker_balgral perio_balgral cierre_balbral observ_balgral  \
# clave_balgral
# 9                     FCFE18         ANUAL     2018-12-31
# 19                   EDUCA18         ANUAL     2019-12-31
# 20                    FCFE18         ANUAL     2019-12-31
# 21                    FMTY14         ANUAL     2019-12-31
# 22                   FNOVA17         ANUAL     2019-12-31
# 23                   FSHOP13         ANUAL     2019-12-31
# 24                    FUNO11         ANUAL     2019-12-31
# 25                   TERRA13         ANUAL     2019-12-31
# 35                   EDUCA18         ANUAL     2020-12-31
# 36                    FCFE18         ANUAL     2020-12-31
# 37                    FMTY14         ANUAL     2020-12-31
# 38                   FNOVA17         ANUAL     2020-12-31
# 39                   FSHOP13         ANUAL     2020-12-31
# 40                    FUNO11         ANUAL     2020-12-31
# 41                   TERRA13         ANUAL     2020-12-31
# ...

# %% [markdown]
# ## Aplicación de lo visto en clase

# %%
# REINDEXADO
# Hacemos una copia del DataFrame
df_edo_res2 = df_edo_res
# Borramos el index origina y asignamos como nuevo index la ubicación de la fila
df_edo_res2 = df_edo_res2.reset_index(drop=True).head(20)
df_edo_res2
# Out:
#    ticker_edores perio_edores observ_edores cierre_edores  vnt_edores  \
# 0         FCFE18        ANUAL                  2018-12-31     4225.46
# 1        EDUCA18        ANUAL                  2019-12-31     2284.25
# 2         FCFE18        ANUAL                  2019-12-31     6367.34
# 3         FMTY14        ANUAL                  2019-12-31     1211.64
# 4        FNOVA17        ANUAL                  2019-12-31      472.32
# 5        FSHOP13        ANUAL                  2019-12-31     1489.78
# 6         FUNO11        ANUAL                  2019-12-31    19189.08
# 7        EDUCA18        ANUAL                  2020-12-31     2959.33
# 8         FCFE18        ANUAL                  2020-12-31     2085.64
# 9         FMTY14        ANUAL                  2020-12-31     1346.96
# 10       FNOVA17        ANUAL                  2020-12-31      561.17
# 11       FSHOP13        ANUAL                  2020-12-31     1346.08
# ...

# %%
# CONCATENACIÓN DE DATAFRAMES - Pd.concat con DataFrames
# Despliegue de los DataFrames
# df_edo_res.head()
# df_bal_gral.head()

# %%
# Concatenamos los DataFrames y cos guardamos en un nuevo DataFrame con reseteo de índice
# df_edores_balgral = pd.concat([df_edo_res, df_bal_gral], axis = 1)
df_edores_balgral = pd.concat([df_edo_res, df_bal_gral], axis = 1).reset_index(drop=True)

# %%
# desplegamos las primeras filas
df_edores_balgral.head(20)
# Out:
#    ticker_edores perio_edores observ_edores cierre_edores  vnt_edores  \
# 0         FCFE18        ANUAL                  2018-12-31     4225.46
# 1        EDUCA18        ANUAL                  2019-12-31     2284.25
# 2         FCFE18        ANUAL                  2019-12-31     6367.34
# 3         FMTY14        ANUAL                  2019-12-31     1211.64
# 4        FNOVA17        ANUAL                  2019-12-31      472.32
# 5        FSHOP13        ANUAL                  2019-12-31     1489.78
# 6         FUNO11        ANUAL                  2019-12-31    19189.08
# 7        EDUCA18        ANUAL                  2020-12-31     2959.33
# 8         FCFE18        ANUAL                  2020-12-31     2085.64
# 9         FMTY14        ANUAL                  2020-12-31     1346.96
# 10       FNOVA17        ANUAL                  2020-12-31      561.17
# 11       FSHOP13        ANUAL                  2020-12-31     1346.08
# ...

# %%
# desplegamos las últimas filas
df_edores_balgral.tail(20)
# Out:
#    ticker_edores perio_edores observ_edores cierre_edores  vnt_edores  \
# 63           NaN          NaN           NaN           NaN         NaN
# 64           NaN          NaN           NaN           NaN         NaN
# 65           NaN          NaN           NaN           NaN         NaN
# 66           NaN          NaN           NaN           NaN         NaN
# 67           NaN          NaN           NaN           NaN         NaN
# 68           NaN          NaN           NaN           NaN         NaN
# 69           NaN          NaN           NaN           NaN         NaN
# 70           NaN          NaN           NaN           NaN         NaN
# 71           NaN          NaN           NaN           NaN         NaN
# 72           NaN          NaN           NaN           NaN         NaN
# 73           NaN          NaN           NaN           NaN         NaN
# 74           NaN          NaN           NaN           NaN         NaN
# ...

# %%
# MERGE
# DataFrames empleados
# df_edo_res
# df_bal_gral

# %%
# Revisamos DataFrames
df_edo_res.head()
# Out:
#              ticker_edores perio_edores observ_edores cierre_edores  \
# clave_edores
# 9                   FCFE18        ANUAL                  2018-12-31
# 19                 EDUCA18        ANUAL                  2019-12-31
# 20                  FCFE18        ANUAL                  2019-12-31
# 21                  FMTY14        ANUAL                  2019-12-31
# 22                 FNOVA17        ANUAL                  2019-12-31
#
#               vnt_edores  vn_edores  ovt_edores  cosven_edores  \
# clave_edores
# 9                4225.46    4225.46         0.0           0.00
# 19               2284.25    2284.25         0.0         207.49
# 20               6367.34    6367.34         0.0           0.00
# 21               1211.64    1211.64         0.0         121.38
# 22                472.32     472.32         0.0           5.94
#
#               uti_bru_edores  gto_ope_edores  ...  tot_parext_edores  \
# clave_edores                                  ...
# ...

# %%
df_bal_gral.head()
# Out:
#               ticker_balgral perio_balgral cierre_balbral observ_balgral  \
# clave_balgral
# 9                     FCFE18         ANUAL     2018-12-31
# 19                   EDUCA18         ANUAL     2019-12-31
# 20                    FCFE18         ANUAL     2019-12-31
# 21                    FMTY14         ANUAL     2019-12-31
# 22                   FNOVA17         ANUAL     2019-12-31
#
#                tac_balgral  eicp_balgral  efectivo_balgral  eee_balgral  \
# clave_balgral
# 9                  1074.16       1073.76              0.00      1073.76
# 19                 1942.57        793.13              0.05       793.08
# 20                25529.62         45.20              0.00        45.20
# 21                 3836.62       3743.55           1522.26      2221.29
# 22                   40.78          5.61              2.65         2.96
#
#                inv_cp_balgral  cxc_balgral  ...  acc_com_balgral  \
# clave_balgral                               ...
# ...

# %%
# pd.merge(df_edo_res.head, df_bal_gral.head, left_on=)
# Pendiente
