# %% [markdown]
# ### Configuración

# %%
# Instalación de MySQL Connector Python y Pandas
# !pip install mysql-connector-python
# !pip install pandas

# %%
# Importación de MySQL Connector y Pandas
import mysql.connector
import pandas as pd

# %%
# Conexión a la base de datos de MySQL
cnx = mysql.connector.connect(
   host="localhost",
   port=3306,
   user="root",
   password='2023*DaSci',
   database='project_processpython'
)

# %%
# REVISAMOS TODAS LAS TABLAS DE LA BASE DE DATOS y Confirmamos el nombre de la tabla 6
# Realización de lecturas a nuestra base de datos creando un objeto llamado cursor.
cursor = cnx.cursor()
# Consulta de tablas
cursor.execute("SHOW TABLES")
#Extracción de información
all_tables = cursor.fetchall()
# all_tables

all_tables[6]

# Para cerrar el cursor
# cursor.close()
# Out:
# ('n15_dividendos',)

# %%
# Realización de lecturas a nuestra base de datos creando un objeto llamado cursor.
cursor = cnx.cursor()
# Consulta de la tabla DIVIDENDOS (n15_dividendos)
cursor.execute("SELECT * FROM n15_dividendos")
#Extracción de información
r_dividendos = cursor.fetchall()
r_dividendos

# Revisión de una fila
# r_dividendos[0]

# Construimos el DataFrame DIVIDENDOS (n15_dividendos)
df_r_dividendos = pd.DataFrame(r_dividendos, columns=['clave_div', 'cierre_div', 'ticker_div', 'fec_ex_div', 'cant_div', 'tipo_div', 'pago_div', 'rendim_div'])

# Convertir la columna clave_div en índice 
df_r_dividendos = df_r_dividendos.set_index('clave_div', drop=True)
df_r_dividendos.head()

# Para cerrar el cursor
# cursor.close()
# Out:
#            cierre_div ticker_div  fec_ex_div  cant_div     tipo_div  \
# clave_div
# 1          2023-08-31   DANHOS13  2023-08-08  0.365318        OTROS
# 2          2023-08-31   DANHOS13  2023-08-08  0.234681  PROVISIONAL
# 3          2023-08-31     FMTY14  2023-08-29  0.074436  PROVISIONAL
# 4          2023-08-31    FNOVA17  2023-08-01  0.506811        OTROS
# 5          2023-08-31     FUNO11  2023-08-07  0.571312   TRIMESTRAL
#
#              pago_div  rendim_div
# clave_div
# 1          2023-08-10      0.0952
# 2          2023-08-10      0.0952
# 3          2023-08-31      0.0000
# 4          2023-08-03      0.0768
# 5          2023-08-09      0.0903

# %% [markdown]
# ### Análisis preliminar de la tabla

# %%
# Dimensiones del DataFrame DIVIDENDOS
df_r_dividendos.shape
# Out:
# (115, 7)

# %%
# Tipos de datos de DataFrame DIVIDENDOS
df_r_dividendos.dtypes
# Out:
# cierre_div     object
# ticker_div     object
# fec_ex_div     object
# cant_div      float64
# tipo_div       object
# pago_div       object
# rendim_div    float64
# dtype: object

# %% [markdown]
# ### Despliegue del DataFrame

# %%
# Despliegue final de todo el DataFrame DIVIDENDOS. Solo se mostrarán algunos resultados.
df_r_dividendos.head(25)
# Out:
#            cierre_div ticker_div  fec_ex_div  cant_div       tipo_div  \
# clave_div
# 1          2023-08-31   DANHOS13  2023-08-08  0.365318          OTROS
# 2          2023-08-31   DANHOS13  2023-08-08  0.234681    PROVISIONAL
# 3          2023-08-31     FMTY14  2023-08-29  0.074436    PROVISIONAL
# 4          2023-08-31    FNOVA17  2023-08-01  0.506811          OTROS
# 5          2023-08-31     FUNO11  2023-08-07  0.571312     TRIMESTRAL
# 6          2023-08-31    TERRA13  2023-08-02  0.442467     TRIMESTRAL
# 7          2023-08-31    EDUCA18  2023-08-22  0.250993         OTROS
# 8          2023-08-31    EDUCA18  2023-08-22  0.319896   PROVISIONAL
# 9          2023-08-31    FSHOP13  2023-08-11  0.066691          OTROS
# 10         2023-07-31     FMTY14  2023-07-27  0.074415    PROVISIONAL
# 11         2023-06-30     FCFE18  2023-06-28  0.367438          OTROS
# 12         2023-06-30     FCFE18  2023-06-28  0.318946    PROVISIONAL
# ...
