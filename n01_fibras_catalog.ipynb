# %% [markdown]
# ### Configuración

# %%
# Instalación de MySQL Connector Python y Pandas
# !pip install mysql-connector-python
# !pip install pandas

# %%
# Importación de MySQL Connector y Pandas
import mysql.connector
import pandas as pd

# %%
# Conexión a la base de datos de MySQL
cnx = mysql.connector.connect(
   host="localhost",
   port=3306,
   user="root",
   password='2023*DaSci',
   database='project_processpython'
)

# %%
# REVISAMOS TODAS LAS TABLAS DE LA BASE DE DATOS y Confirmamos el nombre de la tabla 1
# Realización de lecturas a nuestra base de datos creando un objeto llamado cursor.
cursor = cnx.cursor()
# Consulta de tablas
cursor.execute("SHOW TABLES")
#Extracción de información
all_tables = cursor.fetchall()
all_tables[1]
# Para cerrar el cursor
# cursor.close()
# Out:
# ('n01_fibras_catalog',)

# %%
# Realización de la lectura de la tabla n01_fibras_catalog creando un objeto llamado cursor.
cursor = cnx.cursor()
# Consulta de la tabla CATALOGO DE FIBRAS (n01_fibras_catalog)
cursor.execute("SELECT * FROM n01_fibras_catalog")
#Extracción de información
fibras_catalog = cursor.fetchall()
# fibras_catalog

# Revisión de una fila
# fibras_catalog[0]

# Construimos el DataFrame CATALOGO DE FIBRAS
df_fibras_catalog = pd.DataFrame(fibras_catalog, columns=['ticker', 'emisor', 'inmue_relev', 'year_list', 'sector', 'cant_inmueb', 'tipo_emision', 'isin_ticker'])
# Convertir la columna ticker en índice 
df_fibras_catalog = df_fibras_catalog.set_index('ticker', drop=True)
# Revisión rápida del dataframe
df_fibras_catalog.head()

# Para cerrar el cursor
# cursor.close()
# Out:
#                                                 emisor  \
# ticker
# DANHOS13           Concentradora Fibra Danhos SA de CV
# EDUCA18      Grupo Nagoin SA de CGrupo Nagoin SA de CV
# FCFE18                        CFECapital S de RL de CV
# FEXI21    Mexico Infrastructure Partners F1 SAPI de CV
# FHIPO14           Concentradora Hipotecaria SAPI de CV
#
#                                                 inmue_relev  year_list  \
# ticker
# DANHOS13  Parque Alameda, Parque Delta, Parque Duraznos,...       2013
# EDUCA18   Quick Learning, Instituto Patria MÃ©rida, Univ...       2018
# FCFE18                                            Pendiente       2018
# FEXI21                                            Pendiente       2021
# FHIPO14                                           Pendiente       2014
#
#                 sector  cant_inmueb tipo_emision    isin_ticker
# ticker
# DANHOS13     Comercial           11     Acciones   MXCFDA020005
# ...

# %% [markdown]
# ### Análisis preliminar de la tabla

# %%
# Dimensiones del DataFrame CATALOGO DE FIBRAS
df_fibras_catalog.shape
# Out:
# (20, 7)

# %%
# Tipos de datos de DataFrame CATALOGO DE FIBRAS
df_fibras_catalog.dtypes
# Out:
# emisor          object
# inmue_relev     object
# year_list        int64
# sector          object
# cant_inmueb      int64
# tipo_emision    object
# isin_ticker     object
# dtype: object

# %% [markdown]
# ### Despliegue del DataFrame

# %%
# Despliegue final de todo el DataFrame CATALOGO DE FIBRAS
df_fibras_catalog.head(20)
# Out:
#                                                          emisor  \
# ticker
# DANHOS13                    Concentradora Fibra Danhos SA de CV
# EDUCA18               Grupo Nagoin SA de CGrupo Nagoin SA de CV
# FCFE18                                 CFECapital S de RL de CV
# FEXI21             Mexico Infrastructure Partners F1 SAPI de CV
# FHIPO14                    Concentradora Hipotecaria SAPI de CV
# FIBRAHD15                           FIBRA HD Servicios SC REIT
# FIBRAMQ12     Macquarie Mexico Real Estate Management SA de CV
# FIBRAPL14                     Prologis Property Mexico SA de CV
# FIBRAUP18                             Upsite Mexico SAPI de CV
# FIHO12           Concentradora Fibra Hotelera Mexicana SA de CV
# FINN13                   Administradora de Activos Fibra Inn SC
# FMTY14                                     Fibra Mty SAPI de CV
# FNOVA17            Proyectos Inmobiliarios Carne Mart SA de CV
# FPLUS16                                         Fibra Plus REIT
# ...

# %% [markdown]
# ## Aplicar lo visto en los DataFrames

# %%
# SPLIT
# Separamos los strings de la columna emisor utilizando SPLIT
df_fibras_catalog['emisor'].str.split('\s', expand= True)
# Buscar mas formas de aplicar el SPLIT
# Out:
#                             0               1               2              3  \
# ticker
# DANHOS13        Concentradora           Fibra          Danhos             SA
# EDUCA18                 Grupo          Nagoin              SA             de
# FCFE18             CFECapital               S              de             RL
# FEXI21                 Mexico  Infrastructure        Partners             F1
# FHIPO14         Concentradora     Hipotecaria            SAPI             de
# FIBRAHD15               FIBRA              HD       Servicios             SC
# FIBRAMQ12           Macquarie          Mexico            Real         Estate
# FIBRAPL14            Prologis        Property          Mexico             SA
# FIBRAUP18              Upsite          Mexico            SAPI             de
# FIHO12          Concentradora           Fibra        Hotelera       Mexicana
# FINN13         Administradora              de         Activos          Fibra
# ...
