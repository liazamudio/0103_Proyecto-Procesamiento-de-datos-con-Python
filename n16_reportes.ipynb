# %% [markdown]
# ### Configuración

# %%
# Instalación de MySQL Connector Python y Pandas
# !pip install mysql-connector-python
# !pip install pandas

# %%
# Importación de MySQL Connector y Pandas
import mysql.connector
import pandas as pd

# %%
# Conexión a la base de datos de MySQL
cnx = mysql.connector.connect(
   host="localhost",
   port=3306,
   user="root",
   password='2023*DaSci',
   database='project_processpython'
)

# %%
# REVISAMOS TODAS LAS TABLAS DE LA BASE DE DATOS y Confirmamos el nombre de la tabla 6
# Realización de lecturas a nuestra base de datos creando un objeto llamado cursor.
cursor = cnx.cursor()
# Consulta de tablas
cursor.execute("SHOW TABLES")
#Extracción de información
all_tables = cursor.fetchall()
# all_tables

all_tables[7]

# Para cerrar el cursor
# cursor.close()
# Out:
# ('n16_reportes',)

# %%
# Realización de lecturas a nuestra base de datos creando un objeto llamado cursor.
cursor = cnx.cursor()
# Consulta de la tabla REPORTES (n16_reportes)
cursor.execute("SELECT * FROM n16_reportes")
#Extracción de información
r_reportes = cursor.fetchall()
# r_reportes

# Revisión de una fila
r_reportes[0]

# Para cerrar el cursor
# cursor.close()
# Out:
# (1,
#  datetime.date(2023, 11, 30),
#  ' \tEDUCA18',
#  datetime.date(2023, 11, 29),
#  'sep-23',
#  0.0,
#  0.0,
#  '0',
#  '0')

# %%
# Construimos el DataFrame REPORTES (n16_reportes)
df_r_reportes = pd.DataFrame(r_reportes, columns=['clave_rep', 'fecha_rep', 'ticker_rep', 'pub_rep', 'cierre_rep', 'bpa_log_rep', 'bpa_prev_rep', 'gan_log_rep', 'gan_prev_rep'])

# Convertir la columna clave_rep en índice 
df_r_reportes = df_r_reportes.set_index('clave_rep', drop=True)
df_r_reportes.head()
# Out:
#             fecha_rep  ticker_rep     pub_rep cierre_rep  bpa_log_rep  \
# clave_rep
# 1          2023-11-30   \tEDUCA18  2023-11-29     sep-23          0.0
# 2          2023-11-30   \tFNOVA17  2023-11-29     sep-23          0.0
# 3          2023-10-31    \tFCFE18  2023-10-27     sep-23          0.0
# 4          2023-10-31    \tFUNO11  2023-10-26     sep-23          0.0
# 5          2023-10-31   \tTERRA13  2023-10-26     sep-23          0.0
#
#            bpa_prev_rep gan_log_rep gan_prev_rep
# clave_rep
# 1                0.0000           0            0
# 2                0.0000           0            0
# 3                0.0000           0            0
# 4                0.6122           0         6.34
# 5                0.7061           -            1

# %% [markdown]
# ### Análisis preliminar de la tabla

# %%
# Dimensiones del DataFrame REPORTES
df_r_reportes.shape
# Out:
# (110, 8)

# %%
# Tipos de datos de DataFrame REPORTES
df_r_reportes.dtypes
# Out:
# fecha_rep        object
# ticker_rep       object
# pub_rep          object
# cierre_rep       object
# bpa_log_rep     float64
# bpa_prev_rep    float64
# gan_log_rep      object
# gan_prev_rep     object
# dtype: object

# %% [markdown]
# ### Despliegue del DataFrame

# %%
# Despliegue final de todo el DataFrame REPORTES. Solo se mostrarán algunos resultados.
df_r_reportes.head(30)
# Out:
#             fecha_rep  ticker_rep     pub_rep cierre_rep  bpa_log_rep  \
# clave_rep
# 1          2023-11-30   \tEDUCA18  2023-11-29     sep-23       0.0000
# 2          2023-11-30   \tFNOVA17  2023-11-29     sep-23       0.0000
# 3          2023-10-31    \tFCFE18  2023-10-27     sep-23       0.0000
# 4          2023-10-31    \tFUNO11  2023-10-26     sep-23       0.0000
# 5          2023-10-31   \tTERRA13  2023-10-26     sep-23       0.0000
# 6          2023-10-31    \tFMTY14  2023-10-25     sep-23       0.0000
# 7          2023-10-31   \tFSHOP13  2023-10-23     sep-23       0.0000
# 8          2023-10-31    DANHOS13  2023-10-19     sep-23       0.0000
# 9          2023-08-31   \tEDUCA18  2023-08-30     jun-23       0.0000
# 10         2023-08-31   \tFNOVA17  2023-08-30     jun-23       0.0000
# 11         2023-07-31    \tFCFE18  2023-07-28     jun-23       0.0000
# 12         2023-07-31    \tFUNO11  2023-07-27     jun-23       0.5720
# ...
